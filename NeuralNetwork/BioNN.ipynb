# %%
import keras as k
from keras.models import Sequential
from keras.layers import Dense, Activation
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
train = pd.read_csv("trainData.csv")
test = pd.read_csv("testData.csv")

# %%
#Train set
Y_train = train["Diabetes"]
X_train = train.drop(labels = ["Diabetes"], axis = 1)

sc = StandardScaler()
Y_train = Y_train.values
X_train = sc.fit_transform(X_train.values)

#Validation set
X_train, X_val, Y_train, Y_val = train_test_split(X_train, Y_train, test_size = .1, random_state = 10)

# %%
model = Sequential()
#Architecture
model.add(Dense(32, activation = 'relu'))
model.add(k.layers.Dropout(.1))

model.add(Dense(16, activation = 'relu'))
model.add(k.layers.Dropout(.1))

model.add(Dense(8, activation = 'relu'))

model.add(Dense(4, activation = 'relu'))

model.add(Dense(1))

#Compilation
opt = k.optimizers.nadam(lr=.005)
model.compile(optimizer = opt, loss='mean_squared_error')

#Training
model.fit(X_train, Y_train, epochs=150)
# Out:
# Epoch 1/150
# 179/179 [==============================] - 1s 4ms/step - loss: 52.5533
# Epoch 2/150
# 179/179 [==============================] - 0s 84us/step - loss: 42.7041
# Epoch 3/150
# 179/179 [==============================] - 0s 95us/step - loss: 26.8614
# Epoch 4/150
# 179/179 [==============================] - 0s 84us/step - loss: 16.4439
# Epoch 5/150
# 179/179 [==============================] - 0s 73us/step - loss: 13.6887
# Epoch 6/150
# 179/179 [==============================] - 0s 84us/step - loss: 11.6283
# Epoch 7/150
# 179/179 [==============================] - 0s 62us/step - loss: 11.9452
# Epoch 8/150
# 179/179 [==============================] - 0s 61us/step - loss: 10.2061
# Epoch 9/150
# 179/179 [==============================] - 0s 62us/step - loss: 9.9804
# Epoch 10/150
# 179/179 [==============================] - 0s 56us/step - loss: 9.4655
# Epoch 11/150
# 179/179 [==============================] - 0s 62us/step - loss: 9.1511
# Epoch 12/150
# ...

# %%
model.evaluate(X_val, Y_val, verbose = 1)
# Out:
# 20/20 [==============================] - 0s 7ms/step
# 3.97944974899292

# %%
# predict results
Y_test = test["Diabetes"]
X_test = test.drop(labels = ["Diabetes"], axis = 1)
X_test = sc.fit_transform(X_test.values)
print(Y_test)
results = model.predict(X_test, verbose = 1)
print(results)
# Out:
# 0      6.449201
# 1      3.200000
# 2      3.600000
# 3      7.600000
# 4      7.700000
# 5      6.400000
# 6      7.813140
# 7      7.600000
# 8      3.803725
# 9      6.400000
# 10    10.186501
# 11     6.882491
# 12     7.500000
# 13     4.800000
# 14     4.000000
# 15     3.900000
# 16     7.400000
# 17     5.262266
# 18     3.500000
# 19     8.000000
# Name: Diabetes, dtype: float64
# 20/20 [==============================] - 0s 6ms/step
# [[ 6.0241055]
#  [ 3.9785478]
#  [ 6.6967263]
#  [ 6.5635324]
#  [ 9.299764 ]
#  [ 6.373636 ]
#  [ 4.789572 ]
#  [ 6.795217 ]
#  [ 4.7753   ]
#  [ 9.597328 ]
#  [ 7.465279 ]
#  [ 6.976175 ]
#  [ 8.039807 ]
#  [ 4.686625 ]
#  [ 5.425627 ]
#  [ 4.1985354]
#  [11.150734 ]
#  [ 5.3597198]
#  [ 5.6081123]
#  [ 7.8139625]]
